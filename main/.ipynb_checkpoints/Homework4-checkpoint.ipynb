# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_path = Path("whale_returns.csv")
whale_df = pd.read_csv(whale_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#sort
whale_df.head()
# Out:
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_836\1040573820.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_df = pd.read_csv(whale_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# ...

# %%
# Count
whale_df.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %%
#Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_path = Path("algo_returns.csv")
algo_df = pd.read_csv(algo_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#sort
algo_df.head()
# Out:
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_836\3449745044.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_df = pd.read_csv(algo_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_path = Path("sp500_history.csv")
sp500_history_df = pd.read_csv(sp500_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_history_df.sort_index(inplace=True)
sp500_history_df.head()
# Out:
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_836\3927068652.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_history_df = pd.read_csv(sp500_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_836\3927068652.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_history_df = pd.read_csv(sp500_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
#get rid of $ signs
sp500_history_df['Close'] = sp500_history_df['Close']. str. replace('$', '')
#convert to float
sp500_history_df['Close'] = sp500_history_df['Close'].astype('float')
sp500_history_df
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93
# ...             ...
# 2019-04-16  2907.06
# 2019-04-17  2900.45
# 2019-04-18  2905.03
# 2019-04-22  2907.97
# 2019-04-23  2933.68
#
# [1649 rows x 1 columns]

# %%
# Calculate Daily Returns
sp500_returns_df = sp500_history_df.pct_change()
sp500_returns_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_returns_df.dropna(inplace=True)
sp500_returns_df
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns_df.rename(columns = {'Close':'S&P500'}, inplace = True)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, sp500_returns_df], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
combined_df.sort_index(inplace=True)

# Display a few rows
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    S&P500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize=(20, 10), title='Daily Returns of All Portfolios')
# Out:
# <Axes: title={'center': 'Daily Returns of All Portfolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns_all = (1 + combined_df).cumprod()
cumulative_returns_all.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2    S&P500
# Date
# 2015-03-03  0.999051  0.995461
# 2015-03-04  1.001464  0.991093
# 2015-03-05  1.005794  0.992278
# ...

# %%
# Plot cumulative returns
cumulative_returns_all.plot(figsize=(20, 10), title='Cumulative Returns of All Portfolios')
# Out:
# <Axes: title={'center': 'Cumulative Returns of All Portfolios'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.boxplot(figsize=(20, 10))
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
stddev_all = combined_df.std()
stddev_all.sort_values(inplace=True)
stddev_all
# Out:
# PAULSON & CO.INC.              0.007023
# Algo 1                         0.007620
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 2                         0.008342
# S&P500                         0.008554
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_risk = combined_df['S&P500'].std
sp500_risk
# Determine which portfolios are riskier than the S&P 500
    #These portfolios are all more volatile than the s&p500.
#TIGER GLOBAL MANAGEMENT LLC    0.010894
#BERKSHIRE HATHAWAY INC         0.012919
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of Date
# 2015-03-03   -0.004539
# 2015-03-04   -0.004389
# 2015-03-05    0.001196
# 2015-03-06   -0.014174
# 2015-03-09    0.003944
#                 ...
# 2019-04-16    0.000509
# 2019-04-17   -0.002274
# 2019-04-18    0.001579
# 2019-04-22    0.001012
# 2019-04-23    0.008841
# Name: S&P500, Length: 1043, dtype: float64>

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
stddev_all_annualized = stddev_all * np.sqrt(252)
stddev_all_annualized
# Out:
# PAULSON & CO.INC.              0.111488
# Algo 1                         0.120967
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 2                         0.132430
# S&P500                         0.135786
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling21_stddev_all = combined_df.rolling(window=21).std()
rolling21_stddev_all.plot(figsize=(20, 10), title='Rolling 21 day Standard Deviations')
# Plot the rolling standard deviation
# Out:
# <Axes: title={'center': 'Rolling 21 day Standard Deviations'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation_all = combined_df.corr()
correlation_all
# Display de correlation matrix
sns.heatmap(correlation_all, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance_algo1 = cumulative_returns_all['Algo 1'].rolling(window=60).cov(cumulative_returns_all['S&P500'])
covariance_algo1
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.001112
# 2019-04-17    0.001055
# 2019-04-18    0.001018
# 2019-04-22    0.000972
# 2019-04-23    0.000945
# Length: 1043, dtype: float64

# %%
# Calculate variance of S&P 500
variance_sp500 = cumulative_returns_all['S&P500'].rolling(window=60).var()
variance_sp500
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.001233
# 2019-04-17    0.001191
# 2019-04-18    0.001150
# 2019-04-22    0.001107
# 2019-04-23    0.001104
# Name: S&P500, Length: 1043, dtype: float64

# %%
# Computing beta
algo1_beta = covariance_algo1 / variance_sp500
algo1_beta
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.901439
# 2019-04-17    0.886096
# 2019-04-18    0.884750
# 2019-04-22    0.877978
# 2019-04-23    0.856158
# Length: 1043, dtype: float64

# %%
# Plot beta trend
rolling_beta = covariance_algo1 / variance_sp500
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of Algo 1')
# Out:
# <Axes: title={'center': 'Rolling 30-Day Beta of Algo 1'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_df.ewm(halflife=21).std().plot(figsize=(20, 10), title="Exponentially weighted Average")
# Out:
# <Axes: title={'center': 'Exponentially weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (stddev_all_annualized)
sharpe_ratios.head()
# Out:
# Algo 1                    1.378648
# Algo 2                    0.501364
# BERKSHIRE HATHAWAY INC    0.621810
# PAULSON & CO.INC.        -0.483570
# S&P500                    0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar(figsize=(20, 10),title='Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!
#
# Algo 1 shows higher returns as well as a higher sharpe ratio indicating that it has a desirable risk to reward ratio.  Algo 2 performs worse than the S&P500.  It is actually very heavily correlated to the s&p500, shows worse returns, and shares a similiar risk profile.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
aapl_history_path = Path("aapl_historical.csv")

aapl_history_df = pd.read_csv(aapl_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
aapl_history_df.sort_index(inplace=True)

aapl_history_df
# Out:
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_836\1366836886.py:4: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   aapl_history_df = pd.read_csv(aapl_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#             Close
# Date
# 2015-03-03  32.34
# 2015-03-04  32.14
# 2015-03-05  31.60
# 2015-03-06  31.65
# 2015-03-09  31.79
# ...           ...
# 2019-04-24  51.79
# 2019-04-25  51.32
# 2019-04-26  51.08
# 2019-04-29  51.15
# 2019-04-30  50.17
#
# [1048 rows x 1 columns]

# %%
# Reading data from 2nd stock
nvda_history_path = Path("nvda_historical.csv")
nvda_history_df = pd.read_csv(nvda_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
nvda_history_df.sort_index(inplace=True)
nvda_history_df.head()
# Out:
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_836\682495818.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   nvda_history_df = pd.read_csv(nvda_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#             Close
# Date
# 2015-03-03   5.55
# 2015-03-04   5.61
# 2015-03-05   5.72
# 2015-03-06   5.64
# 2015-03-09   5.65

# %%
# Reading data from 3rd stock
tsla_history_path = Path("tsla_historical.csv")
tsla_history_df = pd.read_csv(tsla_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
tsla_history_df.sort_index(inplace=True)
tsla_history_df.head()
# Out:
# C:\Users\DOUGHJ-WS1\AppData\Local\Temp\ipykernel_836\3582475593.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   tsla_history_df = pd.read_csv(tsla_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
#             Close
# Date
# 2015-03-03  13.30
# 2015-03-04  13.50
# 2015-03-05  13.38
# 2015-03-06  12.93
# 2015-03-09  12.73

# %%
# Combine all stocks in a single DataFrame

my_combined_history = pd.concat([aapl_history_df,nvda_history_df,tsla_history_df], axis='columns', join='inner')
my_combined_history.columns = ["AAPL", "NVDA","TSLA"]

my_combined_history.head()
# Out:
#              AAPL  NVDA   TSLA
# Date
# 2015-03-03  32.34  5.55  13.30
# 2015-03-04  32.14  5.61  13.50
# 2015-03-05  31.60  5.72  13.38
# 2015-03-06  31.65  5.64  12.93
# 2015-03-09  31.79  5.65  12.73

# %%
# Reset Date index
my_combined_history.sort_index(inplace=True)
my_combined_history.head()
# Out:
#              AAPL  NVDA   TSLA
# Date
# 2015-03-03  32.34  5.55  13.30
# 2015-03-04  32.14  5.61  13.50
# 2015-03-05  31.60  5.72  13.38
# 2015-03-06  31.65  5.64  12.93
# 2015-03-09  31.79  5.65  12.73

# %%
# Reorganize portfolio data by having a column per symbol
#Already done

# %%
# Calculate daily returns
my_combined_returns = my_combined_history.pct_change()

# Drop NAs
my_combined_returns.dropna(inplace=True)

# Display sample data
my_combined_returns
# Out:
#                 AAPL      NVDA      TSLA
# Date
# 2015-03-04 -0.006184  0.010811  0.015038
# 2015-03-05 -0.016801  0.019608 -0.008889
# 2015-03-06  0.001582 -0.013986 -0.033632
# 2015-03-09  0.004423  0.001773 -0.015468
# 2015-03-10 -0.020761  0.017699 -0.003142
# ...              ...       ...       ...
# 2019-04-24 -0.001542  0.002517 -0.019898
# 2019-04-25 -0.009075 -0.022180 -0.042343
# 2019-04-26 -0.004677 -0.047293 -0.050273
# 2019-04-29  0.001370  0.006963  0.026786
# 2019-04-30 -0.019159  0.009369 -0.011801
#
# [1047 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_portfolio_returns = my_combined_returns.dot(weights)


# Display sample data
my_portfolio_returns.head()
# Out:
# Date
# 2015-03-04    0.006555
# 2015-03-05   -0.002028
# 2015-03-06   -0.015345
# 2015-03-09   -0.003090
# 2015-03-10   -0.002068
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
my_combined_returns = pd.concat([combined_df,my_portfolio_returns], axis='columns', join='inner')

my_combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# 2015-03-10                    -0.012079               -0.009739 -0.001392
#
#               Algo 2    S&P500         0
# Date
# 2015-03-04  0.002416 -0.004389  0.006555
# 2015-03-05  0.004323  0.001196 -0.002028
# ...

# %%
#Fixed my portfolios column name
my_combined_returns.rename(columns={0: "My Portfolio"}, inplace=True, errors="raise")
my_combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# 2015-03-10                    -0.012079               -0.009739 -0.001392
#
#               Algo 2    S&P500  My Portfolio
# Date
# 2015-03-04  0.002416 -0.004389      0.006555
# 2015-03-05  0.004323  0.001196     -0.002028
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
#looks good
my_combined_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P500                         0
# My Portfolio                   0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
stddev_all_portfolios = my_combined_returns.std()
stddev_all_portfolios.sort_values(inplace=True)
stddev_all_portfolios
# Out:
# PAULSON & CO.INC.              0.007025
# Algo 1                         0.007623
# SOROS FUND MANAGEMENT LLC      0.007899
# Algo 2                         0.008346
# S&P500                         0.008556
# TIGER GLOBAL MANAGEMENT LLC    0.010899
# BERKSHIRE HATHAWAY INC         0.012923
# My Portfolio                   0.017635
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling21_stddev_all_portfolios = my_combined_returns.rolling(window=21).std()
rolling21_stddev_all_portfolios.plot(figsize=(20, 10), title='Rolling 21 day Standard Deviations')
# Plot rolling standard deviation
# Out:
# <Axes: title={'center': 'Rolling 21 day Standard Deviations'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
# Calculate the correlation
correlation_all_portfolios = my_combined_returns.corr()
correlation_all_portfolios
# Display de correlation matrix
sns.heatmap(correlation_all_portfolios, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
covariance_my_portfolio = my_combined_returns['My Portfolio'].rolling(window=60).cov(cumulative_returns_all['S&P500'])
covariance_my_portfolio

variance_sp500

algo1_beta = covariance_my_portfolio / variance_sp500
algo1_beta

rolling_beta_my_portfolio = covariance_my_portfolio / variance_sp500
rolling_beta_my_portfolio.plot(figsize=(20, 10), title='Rolling 60-Day Beta of My Portfolio')
# Out:
# <Axes: title={'center': 'Rolling 60-Day Beta of My Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios_all = (my_combined_returns.mean() * 252) / ((stddev_all_portfolios) * np.sqrt(252))
sharpe_ratios_all.sort_values(inplace=True)
sharpe_ratios_all
# Out:
# PAULSON & CO.INC.             -0.473108
# TIGER GLOBAL MANAGEMENT LLC   -0.120425
# SOROS FUND MANAGEMENT LLC      0.359034
# Algo 2                         0.503342
# BERKSHIRE HATHAWAY INC         0.629941
# S&P500                         0.656761
# My Portfolio                   1.102998
# Algo 1                         1.383268
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_all.plot.bar(figsize=(20, 10),title='Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# My portfolio was volatile and aggressive.  It showed strong returns but also high volatility.  That said it had a fairly positive sharpe ratio and so had a desirable risk/reward profile.  It showed strong correlation to the s&p500 but not as badly as algo 2.  Below I prepared a graph showing a theoretical $10000 investment.  I think it shows what I have already described, high investment opportunity, but you need a stomach for volatility.

# %%
my_cumulative_returns = (1 + my_portfolio_returns).cumprod()
my_cumulative_returns.head()
# Out:
# Date
# 2015-03-04    1.006555
# 2015-03-05    1.004514
# 2015-03-06    0.989099
# 2015-03-09    0.986042
# 2015-03-10    0.984003
# dtype: float64

# %%
initial_investment = 10000
cumulative_profit = initial_investment * my_cumulative_returns
cumulative_profit.plot()
# Out:
# <Axes: xlabel='Date'>
